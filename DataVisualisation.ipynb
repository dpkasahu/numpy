# %% [markdown]
# <a href="https://colab.research.google.com/github/dpkasahu/Python_library/blob/main/DataVisualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Representation of data in graphical format is known as data visualization.
# these we can do with
# 1) matplotlib
# 2)seaborn


# 1)matplotlib
# import matplotlib.pyplot as plt
# plot is responsible to provide 2-D graphs

#syntax
# plt.plot(array1,array2)

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,3,4,5])
y=x**2
plt.plot(x,y,marker='p',color='brown',markerfacecolor='blue',markersize=10,markeredgecolor='black')
#to use plot the length of x and y must be same

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([1,2,3,4,5])
y = x**2
z=x**3
a=x**4
# plt.scatter(x, y)
# plt.bar(x, y)
# plt.plot(x, y, linestyle='--', marker='o')
# plt.show()
plt.fill_between(x, y, color='skyblue', alpha=0.3, label='Square')
plt.plot(x, z, color='orange', alpha=0.3 , label='Cube')
plt.plot(x, a, color='black', alpha=0.3 , label='PowerFour')
plt.legend()
# plt.title()
plt.plot(x, y)
plt.plot(x, z,label='cube')
plt.xlabel('Numbers',c='brown')
plt.ylabel('Squares',c='brown')
# Out:
# Text(0, 0.5, 'Squares')

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/whoknowayush/DataAnalysis-Dataset/refs/heads/main/Datasets-Practice/employee_data.csv')
df
# Out:
#     emp_id             full_name   age  gender department   salary  \
# 0      101         John A. Smith  28.0    male      Sales  45000.0
# 1      102    Sarah-Louise James   NaN  female  Marketing  50000.0
# 2      110          Rajesh Kumar  45.0    male      Sales  90000.0
# 3      103        Mark O'Donnell  35.0    male         HR  52000.0
# 4      104   Emily Jackson-Smith  29.0  female        R&D  65000.0
# 5      102    Sarah-Louise James   NaN  female  Marketing  50000.0
# 6      110          Rajesh Kumar  45.0    male      Sales  90000.0
# 7      105     Samuel L. Jackson  42.0    Male         IT      NaN
# 8      106           Priya Ghosh  31.0     NaN  Marketing  58000.0
# 9      102    Sarah-Louise James   NaN  female  Marketing  50000.0
# 10     110          Rajesh Kumar  45.0    male      Sales  90000.0
# 11     107     Susan M. Thompson  39.0  Female         IT  75000.0
# 12     108     Brian P. McDonald  33.0    Male         HR  48000.0
# ...

# %%
plt.plot(df['salary'], df['exp_years'],color='brown',marker='o')
# plt.figure(figsize=(10,10))
plt.xlabel('Salary')
plt.ylabel('Experience')
# Out:
# Text(0, 0.5, 'Experience')

# %%
plt.figure(figsize=(20,20))

plt.subplot(2,3,1)
plt.plot(df['age'], df['salary'], color='brown', marker='o')
plt.xlabel('Age')
plt.ylabel('Salary')

plt.subplot(2,3,2)
plt.plot(df['age'], df['exp_years'], color='brown', marker='o')
plt.xlabel('Age')
plt.ylabel('Experience')

plt.subplot(2,3,3)
plt.plot(df['salary'], df['exp_years'], color='brown', marker='o')
plt.xlabel('Salary')
plt.ylabel('Experience')

plt.subplot(2,3,4)
plt.plot(df['salary'], df['age'], color='brown', marker='o')
plt.xlabel('Salary')
plt.ylabel('Age')

plt.subplot(2,3,5)
plt.plot(df['exp_years'], df['age'], color='brown', marker='o')
plt.xlabel('Experience')
plt.ylabel('Age')

plt.subplot(2,3,6)
plt.plot(df['exp_years'], df['salary'], color='brown', marker='o')
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.show()
plt.tight_layout()
# plt.subplot(row,column,index)

# %%
#fig,axes=plt.subplots((row,columns),figsize=(width,height))
fig,axes=plt.subplots(2,2)
axes[0][0].plot(x,y,marker='.',color='black')
axes[0][0].set_facecolor('beige')
axes[0][1].plot(x,z,marker='.',color='black')
axes[0][1].set_facecolor('orange')
axes[1][0].plot(x,a,marker='.',color='black')
axes[1][0].set_facecolor('brown')
axes[1][1].plot(z,y,marker='.',color='black')
axes[1][1].set_facecolor('pink')
plt.tight_layout() #it will adjust the sizes
