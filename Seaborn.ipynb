# %% [markdown]
# <a href="https://colab.research.google.com/github/dpkasahu/Python_library/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# It is an python library used for data visualization to handle complex dataset.
# ---
#  we can create 4 types of plot
#  ---
#  1)Distributed plot
#  2)Categorical plot
#  3)Matrix plot
#  4)Regression plot

# %% [markdown]
# Distribution plot :-
# it is used to create or plotting between numerical columns.
#
# if datatype == object ,
# it will throw new error
# --
# 1)displot
# 2)jointplot
# 3)pairplot

# %%
import seaborn as sns

# %%
sb1=sns.load_dataset('iris')
sb1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.distplot(sb1['sepal_length'],bins=20)
# Out:
# /tmp/ipython-input-1199944802.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sb1['sepal_length'],bins=20)
# <Axes: xlabel='sepal_length', ylabel='Density'>
