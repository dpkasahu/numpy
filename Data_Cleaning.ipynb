# %% [markdown]
# <a href="https://colab.research.google.com/github/dpkasahu/Python_library/blob/main/Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df1=pd.DataFrame({'st_name':['karan','Arjun','Rohan','Mohan','Rohan','Arjun'],
                  'st_id':[102,103,104,105,104,106],
                  'st_p':[76543212,84432434,97654324,87654345,97654324,87654345],
                  'st_age':[16,17,16,16,16,17],
                  'st_marks':[98,87,89,78,89,78],
                  'st_age':[19,16,15,17,15,15]})

# %%
df1
# Out:
#   st_name  st_id      st_p  st_age  st_marks
# 0   karan    102  76543212      19        98
# 1   Arjun    103  84432434      16        87
# 2   Rohan    104  97654324      15        89
# 3   Mohan    105  87654345      17        78
# 4   Rohan    104  97654324      15        89
# 5   Arjun    106  87654345      15        78

# %%
df1.drop_duplicates(inplace=True)

# %%
df1
# Out:
#   st_name  st_id      st_p  st_age  st_marks
# 0   karan    102  76543212      19        98
# 1   Arjun    103  84432434      16        87
# 2   Rohan    104  97654324      15        89
# 3   Mohan    105  87654345      17        78
# 5   Arjun    106  87654345      15        78

# %%
upd_marks={98:95,87:90,89:96,78:70}
df1['st_marks']=df1['st_marks'].map(upd_marks)

# include all the unique values otherwise it will provide NaN value

# %%
df1
# Out:
#   st_name  st_id      st_p  st_age  st_marks
# 0   karan    102  76543212      19        95
# 1   Arjun    103  84432434      16        90
# 2   Rohan    104  97654324      15        96
# 3   Mohan    105  87654345      17        70
# 5   Arjun    106  87654345      15        70

# %%
upd_marks={98:95,87:90}
df1['st_marks']=df1['st_marks'].replace(upd_marks)

# %%
df1
# Out:
#   st_name  st_id      st_p  st_age  st_marks
# 0   karan    102  76543212      19        95
# 1   Arjun    103  84432434      16        90
# 2   Rohan    104  97654324      15        96
# 3   Mohan    105  87654345      17        70
# 5   Arjun    106  87654345      15        70

# %%
# changing column
# st_p-->st_phno
#st_marks--->st_score
#ch={'st_p':'st_phno'}

df1.rename(columns={'st_p':'st_phno','st_marks':'st_score'},inplace=True)
# by default inplace=False which will not change permanently

# %%
df1
# Out:
#   st_name  st_id   st_phno  st_age  st_score
# 0   karan    102  76543212      19        95
# 1   Arjun    103  84432434      16        90
# 2   Rohan    104  97654324      15        96
# 3   Mohan    105  87654345      17        70
# 5   Arjun    106  87654345      15        70

# %%
# st_id--->st_rollno
# st_age-->age
# st_name--->st

df1.drop_duplicates()
# it will remove the duplicates from the dataframe which are having same column
# Out:
#   st_name  st_id   st_phno  st_age  st_score
# 0   karan    102  76543212      19        95
# 1   Arjun    103  84432434      16        90
# 2   Rohan    104  97654324      15        96
# 3   Mohan    105  87654345      17        70
# 5   Arjun    106  87654345      15        70

# %%
df4=pd.read_csv('/content/amazon_fires.csv',encoding='ISO-8859-1')

# %%
df4.head()
# Out:
#     ano      mes estado   numero  encontro
# 0  1998  Janeiro   Acre  0 Fires  1/1/1998
# 1  1999  Janeiro   Acre  0 Fires  1/1/1999
# 2  2000  Janeiro   Acre  0 Fires  1/1/2000
# 3  2001  Janeiro   Acre  0 Fires  1/1/2001
# 4  2002  Janeiro   Acre  0 Fires  1/1/2002

# %%
df4.describe()
# Out:
#                ano
# count  6454.000000
# mean   2007.461729
# std       5.746654
# min    1998.000000
# 25%    2002.000000
# 50%    2007.000000
# 75%    2012.000000
# max    2017.000000

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6454 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ano       6454 non-null   int64
#  1   mes       6454 non-null   object
#  2   estado    6454 non-null   object
#  3   numero    6322 non-null   object
#  4   encontro  6454 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 252.2+ KB

# %%
dict1={'ano':'year','mes':'month','estado':'state','numero':'number of fires','encontro':'date'}

# %%
df4.rename(columns=dict1,inplace =True)

# %%
df4
# Out:
#       year     month      state number of fires      date
# 0     1998   Janeiro       Acre         0 Fires  1/1/1998
# 1     1999   Janeiro       Acre         0 Fires  1/1/1999
# 2     2000   Janeiro       Acre         0 Fires  1/1/2000
# 3     2001   Janeiro       Acre         0 Fires  1/1/2001
# 4     2002   Janeiro       Acre         0 Fires  1/1/2002
# ...    ...       ...        ...             ...       ...
# 6449  2012  Dezembro  Tocantins             128  1/1/2012
# 6450  2013  Dezembro  Tocantins              85  1/1/2013
# 6451  2014  Dezembro  Tocantins             223  1/1/2014
# 6452  2015  Dezembro  Tocantins             373  1/1/2015
# 6453  2016  Dezembro  Tocantins             119  1/1/2016
#
# [6454 rows x 5 columns]

# %%
df4['month'].unique()
# Out:
# array(['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho',
#        'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro'],
#       dtype=object)

# %%
dict2={'Janeiro':'January', 'Fevereiro':'February', 'Março':'March', 'Abril':'April', 'Maio':"May", 'Junho':'June', 'Julho':'July',
       'Agosto':'August', 'Setembro':'September', 'Outubro':'October', 'Novembro':'November', 'Dezembro':'December'}

# %%
df4['month']=df4['month'].map(dict2)

# %%
df4
# Out:
#       year     month      state number of fires      date
# 0     1998   January       Acre         0 Fires  1/1/1998
# 1     1999   January       Acre         0 Fires  1/1/1999
# 2     2000   January       Acre         0 Fires  1/1/2000
# 3     2001   January       Acre         0 Fires  1/1/2001
# 4     2002   January       Acre         0 Fires  1/1/2002
# ...    ...       ...        ...             ...       ...
# 6449  2012  December  Tocantins             128  1/1/2012
# 6450  2013  December  Tocantins              85  1/1/2013
# 6451  2014  December  Tocantins             223  1/1/2014
# 6452  2015  December  Tocantins             373  1/1/2015
# 6453  2016  December  Tocantins             119  1/1/2016
#
# [6454 rows x 5 columns]

# %%
from numpy._core.fromnumeric import size
# df4['mon'] = df4['month'].str.slice(stop=3)
# df4['mon'] = df4['month'].str[:3]
df4['mon'] = [i[-3:] for i in df4['month']]
df4
# Out:
#       year     month      state  number of fires  mon
# 0     2000   January       Acre              0.0  ary
# 1     2002   January       Acre              0.0  ary
# 2     2003   January       Acre             10.0  ary
# 3     2004   January       Acre              0.0  ary
# 4     2005   January       Acre             12.0  ary
# ...    ...       ...        ...              ...  ...
# 6446  2012  December  Tocantins            128.0  ber
# 6447  2013  December  Tocantins             85.0  ber
# 6448  2014  December  Tocantins            223.0  ber
# 6449  2015  December  Tocantins            373.0  ber
# 6450  2016  December  Tocantins            119.0  ber
#
# [6451 rows x 5 columns]

# %%
df4.head()
# Out:
#    year    month state number of fires      date
# 0  1998  January  Acre         0 Fires  1/1/1998
# 1  1999  January  Acre         0 Fires  1/1/1999
# 2  2000  January  Acre         0 Fires  1/1/2000
# 3  2001  January  Acre         0 Fires  1/1/2001
# 4  2002  January  Acre         0 Fires  1/1/2002

# %%
df4.tail()
# Out:
#       year     month      state number of fires      date
# 6449  2012  December  Tocantins             128  1/1/2012
# 6450  2013  December  Tocantins              85  1/1/2013
# 6451  2014  December  Tocantins             223  1/1/2014
# 6452  2015  December  Tocantins             373  1/1/2015
# 6453  2016  December  Tocantins             119  1/1/2016

# %%
(df4['number of fires'][0])
# Out:
# '0 Fires'

# %%
df4['number of fires']=df4['number of fires'].str.strip(' Fires')

# %%
df4
# Out:
#       year     month      state number of fires      date
# 0     1998   January       Acre               0  1/1/1998
# 1     1999   January       Acre               0  1/1/1999
# 2     2000   January       Acre               0  1/1/2000
# 3     2001   January       Acre               0  1/1/2001
# 4     2002   January       Acre               0  1/1/2002
# ...    ...       ...        ...             ...       ...
# 6449  2012  December  Tocantins             128  1/1/2012
# 6450  2013  December  Tocantins              85  1/1/2013
# 6451  2014  December  Tocantins             223  1/1/2014
# 6452  2015  December  Tocantins             373  1/1/2015
# 6453  2016  December  Tocantins             119  1/1/2016
#
# [6454 rows x 5 columns]

# %%
df4[df4['number of fires'].isnull()]
# Out:
#       year      month      state number of fires      date
# 68    2006      April       Acre             NaN  1/1/2006
# 110   2008       June       Acre             NaN  1/1/2008
# 127   2005       July       Acre             NaN  1/1/2005
# 206   2004   November       Acre             NaN  1/1/2004
# 217   2015   November       Acre             NaN  1/1/2015
# ...    ...        ...        ...             ...       ...
# 6305  2008        May  Tocantins             NaN  1/1/2008
# 6354  2017       July  Tocantins             NaN  1/1/2017
# 6383  2006  September  Tocantins             NaN  1/1/2006
# 6415  1998   November  Tocantins             NaN  1/1/1998
# 6428  2011   November  Tocantins             NaN  1/1/2011
#
# [132 rows x 5 columns]

# %%
#df4.dropna(inplace=True)

# %%
df4['mon'] = df4['month'].str.slice(stop=3)

# %%
#df4['number of fires']=df4['number of fires'].astype(float)
#df4['number of fires']=df4['number of fires'].astype(int)

# %%
df4
# Out:
#       year     month      state number of fires      date  mon
# 0     1998   January       Acre               0  1/1/1998  Jan
# 1     1999   January       Acre               0  1/1/1999  Jan
# 2     2000   January       Acre               0  1/1/2000  Jan
# 3     2001   January       Acre               0  1/1/2001  Jan
# 4     2002   January       Acre               0  1/1/2002  Jan
# ...    ...       ...        ...             ...       ...  ...
# 6449  2012  December  Tocantins             128  1/1/2012  Dec
# 6450  2013  December  Tocantins              85  1/1/2013  Dec
# 6451  2014  December  Tocantins             223  1/1/2014  Dec
# 6452  2015  December  Tocantins             373  1/1/2015  Dec
# 6453  2016  December  Tocantins             119  1/1/2016  Dec
#
# [6454 rows x 6 columns]

# %%
type(df4['number of fires'][0])
# Out:
# str

# %%
#mean=df4['number of fires'].mean()
mean=110.6

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6454 entries, 0 to 6453
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             6454 non-null   int64
#  1   month            6454 non-null   object
#  2   state            6454 non-null   object
#  3   number of fires  6322 non-null   object
#  4   date             6454 non-null   object
#  5   mon              6454 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 302.7+ KB

# %%
df4['number of fires']=df4['number of fires'].fillna(mean)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6454 entries, 0 to 6453
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             6454 non-null   int64
#  1   month            6454 non-null   object
#  2   state            6454 non-null   object
#  3   number of fires  6454 non-null   object
#  4   date             6454 non-null   object
#  5   mon              6454 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 302.7+ KB

# %%
float('14.5')
# Out:
# 14.5

# %%
df4=df4[df4.columns[[3,2,1,0,4]]]

# %%
df4
# Out:
#      number of fires      state     month  year      date
# 0                  0       Acre   January  1998  1/1/1998
# 1                  0       Acre   January  1999  1/1/1999
# 2                  0       Acre   January  2000  1/1/2000
# 3                  0       Acre   January  2001  1/1/2001
# 4                  0       Acre   January  2002  1/1/2002
# ...              ...        ...       ...   ...       ...
# 6449             128  Tocantins  December  2012  1/1/2012
# 6450              85  Tocantins  December  2013  1/1/2013
# 6451             223  Tocantins  December  2014  1/1/2014
# 6452             373  Tocantins  December  2015  1/1/2015
# 6453             119  Tocantins  December  2016  1/1/2016
#
# [6454 rows x 5 columns]

# %%
df4.drop(['state','month'],axis=1)
# Out:
#      number of fires  year      date
# 0                  0  1998  1/1/1998
# 1                  0  1999  1/1/1999
# 2                  0  2000  1/1/2000
# 3                  0  2001  1/1/2001
# 4                  0  2002  1/1/2002
# ...              ...   ...       ...
# 6449             128  2012  1/1/2012
# 6450              85  2013  1/1/2013
# 6451             223  2014  1/1/2014
# 6452             373  2015  1/1/2015
# 6453             119  2016  1/1/2016
#
# [6454 rows x 3 columns]

# %%
df4.drop(df4.index[0])
# Out:
#      number of fires      state     month  year      date
# 1                  0       Acre   January  1999  1/1/1999
# 2                  0       Acre   January  2000  1/1/2000
# 3                  0       Acre   January  2001  1/1/2001
# 4                  0       Acre   January  2002  1/1/2002
# 5                 10       Acre   January  2003  1/1/2003
# ...              ...        ...       ...   ...       ...
# 6449             128  Tocantins  December  2012  1/1/2012
# 6450              85  Tocantins  December  2013  1/1/2013
# 6451             223  Tocantins  December  2014  1/1/2014
# 6452             373  Tocantins  December  2015  1/1/2015
# 6453             119  Tocantins  December  2016  1/1/2016
#
# [6453 rows x 5 columns]

# %%
df4['number of fires']=pd.to_numeric(df4['number of fires'])
# Out:
# /tmp/ipython-input-3873709784.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['number of fires']=pd.to_numeric(df4['number of fires'])

# %%
df4
# Out:
#       number of fires      state     month  year      date
# 0                 0.0       Acre   January  1998  1/1/1998
# 1                 0.0       Acre   January  1999  1/1/1999
# 2                 0.0       Acre   January  2000  1/1/2000
# 3                 0.0       Acre   January  2001  1/1/2001
# 4                 0.0       Acre   January  2002  1/1/2002
# ...               ...        ...       ...   ...       ...
# 6449            128.0  Tocantins  December  2012  1/1/2012
# 6450             85.0  Tocantins  December  2013  1/1/2013
# 6451            223.0  Tocantins  December  2014  1/1/2014
# 6452            373.0  Tocantins  December  2015  1/1/2015
# 6453            119.0  Tocantins  December  2016  1/1/2016
#
# [6454 rows x 5 columns]

# %%
mean = df4['number of fires'].mean()
mean
# Out:
# np.float64(110.66658134490237)

# %%
df4[df4['number of fires'].isnull()].count()
# Out:
# number of fires    0
# state              0
# month              0
# year               0
# date               0
# dtype: int64

# %%
df4['number of fires']=df4['number of fires'].fillna(mean)
# Out:
# /tmp/ipython-input-3515662403.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['number of fires']=df4['number of fires'].fillna(mean)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6454 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   number of fires  6454 non-null   float64
#  1   state            6454 non-null   object
#  2   month            6454 non-null   object
#  3   year             6454 non-null   int64
#  4   date             6454 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 252.2+ KB

# %%
#df.to_csv(filename.csv)
df4.to_csv('amazon_fires_cleaned.csv')

# %%
df4.drop('state',axis=1)
# Out:
#       number of fires     month  year      date
# 0                 0.0   January  1998  1/1/1998
# 1                 0.0   January  1999  1/1/1999
# 2                 0.0   January  2000  1/1/2000
# 3                 0.0   January  2001  1/1/2001
# 4                 0.0   January  2002  1/1/2002
# ...               ...       ...   ...       ...
# 6449            128.0  December  2012  1/1/2012
# 6450             85.0  December  2013  1/1/2013
# 6451            223.0  December  2014  1/1/2014
# 6452            373.0  December  2015  1/1/2015
# 6453            119.0  December  2016  1/1/2016
#
# [6454 rows x 4 columns]

# %%
df4
# Out:
#       number of fires      state     month  year      date
# 0                 0.0       Acre   January  1998  1/1/1998
# 1                 0.0       Acre   January  1999  1/1/1999
# 2                 0.0       Acre   January  2000  1/1/2000
# 3                 0.0       Acre   January  2001  1/1/2001
# 4                 0.0       Acre   January  2002  1/1/2002
# ...               ...        ...       ...   ...       ...
# 6449            128.0  Tocantins  December  2012  1/1/2012
# 6450             85.0  Tocantins  December  2013  1/1/2013
# 6451            223.0  Tocantins  December  2014  1/1/2014
# 6452            373.0  Tocantins  December  2015  1/1/2015
# 6453            119.0  Tocantins  December  2016  1/1/2016
#
# [6454 rows x 5 columns]

# %%
df4.drop(['year','month'],axis=1)
# Out:
#       number of fires      state      date
# 0                 0.0       Acre  1/1/1998
# 1                 0.0       Acre  1/1/1999
# 2                 0.0       Acre  1/1/2000
# 3                 0.0       Acre  1/1/2001
# 4                 0.0       Acre  1/1/2002
# ...               ...        ...       ...
# 6449            128.0  Tocantins  1/1/2012
# 6450             85.0  Tocantins  1/1/2013
# 6451            223.0  Tocantins  1/1/2014
# 6452            373.0  Tocantins  1/1/2015
# 6453            119.0  Tocantins  1/1/2016
#
# [6454 rows x 3 columns]

# %% [markdown]
# ### How to drop specific indices from `df4`

# %%
df4.drop(df4.index[[0,1,3,4]],axis=0)
# Out:
#       number of fires      state     month  year      date
# 2                 0.0       Acre   January  2000  1/1/2000
# 5                10.0       Acre   January  2003  1/1/2003
# 6                 0.0       Acre   January  2004  1/1/2004
# 7                12.0       Acre   January  2005  1/1/2005
# 8                 4.0       Acre   January  2006  1/1/2006
# ...               ...        ...       ...   ...       ...
# 6449            128.0  Tocantins  December  2012  1/1/2012
# 6450             85.0  Tocantins  December  2013  1/1/2013
# 6451            223.0  Tocantins  December  2014  1/1/2014
# 6452            373.0  Tocantins  December  2015  1/1/2015
# 6453            119.0  Tocantins  December  2016  1/1/2016
#
# [6450 rows x 5 columns]

# %%
df4.drop([0,1,3],inplace=True)
# Out:
# /tmp/ipython-input-858525819.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4.drop([0,1,3],inplace=True)

# %%
#dropping the rows
# df.drop([ind1,ind2,ind3....indn],axis = 0)
# or
# df.drop(df.index[[ind1,ind2,ind3....indn]],axis = 0)
#or
#df.drop(df.index[ind1,ind2,ind3...indn])

# %%
df4.reset_index(inplace=True)

# %%
df4.columns
# Out:
# Index(['index', 'number of fires', 'state', 'month', 'year', 'date'], dtype='object')

# %%
df4.drop('index',axis=1,inplace=True)
# Out:
# /tmp/ipython-input-3269150045.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4.drop('index',axis=1,inplace=True)

# %%
df4
# Out:
#       number of fires      state     month  year      date
# 0                 0.0       Acre   January  2000  1/1/2000
# 1                 0.0       Acre   January  2002  1/1/2002
# 2                10.0       Acre   January  2003  1/1/2003
# 3                 0.0       Acre   January  2004  1/1/2004
# 4                12.0       Acre   January  2005  1/1/2005
# ...               ...        ...       ...   ...       ...
# 6446            128.0  Tocantins  December  2012  1/1/2012
# 6447             85.0  Tocantins  December  2013  1/1/2013
# 6448            223.0  Tocantins  December  2014  1/1/2014
# 6449            373.0  Tocantins  December  2015  1/1/2015
# 6450            119.0  Tocantins  December  2016  1/1/2016
#
# [6451 rows x 5 columns]

# %%
df4.set_index('year')
# Out:
#       number of fires      state     month      date
# year
# 2000              0.0       Acre   January  1/1/2000
# 2002              0.0       Acre   January  1/1/2002
# 2003             10.0       Acre   January  1/1/2003
# 2004              0.0       Acre   January  1/1/2004
# 2005             12.0       Acre   January  1/1/2005
# ...               ...        ...       ...       ...
# 2012            128.0  Tocantins  December  1/1/2012
# 2013             85.0  Tocantins  December  1/1/2013
# 2014            223.0  Tocantins  December  1/1/2014
# 2015            373.0  Tocantins  December  1/1/2015
# 2016            119.0  Tocantins  December  1/1/2016
#
# [6451 rows x 4 columns]

# %%
df5=pd.read_csv('https://raw.githubusercontent.com/whoknowayush/DataAnalysis-Dataset/refs/heads/main/Datasets-Practice/winequalityN.csv')
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
df5.drop_duplicates().count()
# Out:
# type                    5329
# fixed acidity           5319
# volatile acidity        5321
# citric acid             5326
# residual sugar          5327
# chlorides               5327
# free sulfur dioxide     5329
# total sulfur dioxide    5329
# density                 5329
# pH                      5320
# sulphates               5325
# alcohol                 5329
# quality                 5329
# dtype: int64

# %%
df5.isnull().count()
# Out:
# type                    6497
# fixed acidity           6497
# volatile acidity        6497
# citric acid             6497
# residual sugar          6497
# chlorides               6497
# free sulfur dioxide     6497
# total sulfur dioxide    6497
# density                 6497
# pH                      6497
# sulphates               6497
# alcohol                 6497
# quality                 6497
# dtype: int64

# %%
df5
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df5=df5.drop_duplicates(inplace=True)

# %%
df5 = pd.read_csv('https://raw.githubusercontent.com/whoknowayush/DataAnalysis-Dataset/refs/heads/main/Datasets-Practice/winequalityN.csv')
df5 = df5.drop_duplicates()
df5.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
df5=df5.dropna()
df5=df5.fillna(mean)

# %%
col = df5.mean(numeric_only=True)
df5=df5.fillna(col)

# %%
import pandas as pd
df5 = pd.read_csv('https://raw.githubusercontent.com/whoknowayush/DataAnalysis-Dataset/refs/heads/main/Datasets-Practice/winequalityN.csv')
df5 = df5.drop_duplicates()
df5_means = df5.mean(numeric_only=True)
df5 = df5.fillna(df5_means)
df5 = df5.reset_index()

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5329 entries, 0 to 5328
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 5329 non-null   int64
#  1   type                  5329 non-null   object
#  2   fixed acidity         5329 non-null   float64
#  3   volatile acidity      5329 non-null   float64
#  4   citric acid           5329 non-null   float64
#  5   residual sugar        5329 non-null   float64
#  6   chlorides             5329 non-null   float64
#  7   free sulfur dioxide   5329 non-null   float64
#  8   total sulfur dioxide  5329 non-null   float64
#  9   density               5329 non-null   float64
#  10  pH                    5329 non-null   float64
#  11  sulphates             5329 non-null   float64
#  12  alcohol               5329 non-null   float64
#  13  quality               5329 non-null   int64
# dtypes: float64(11), int64(2), object(1)
# ...

# %%
df5= df5.drop(columns=["index"])

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5329 entries, 0 to 5328
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  5329 non-null   object
#  1   fixed acidity         5329 non-null   float64
#  2   volatile acidity      5329 non-null   float64
#  3   citric acid           5329 non-null   float64
#  4   residual sugar        5329 non-null   float64
#  5   chlorides             5329 non-null   float64
#  6   free sulfur dioxide   5329 non-null   float64
#  7   total sulfur dioxide  5329 non-null   float64
#  8   density               5329 non-null   float64
#  9   pH                    5329 non-null   float64
#  10  sulphates             5329 non-null   float64
#  11  alcohol               5329 non-null   float64
#  12  quality               5329 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 541.4+ KB

# %%
df5
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            6.2             0.320         0.16             7.0
# ...     ...            ...               ...          ...             ...
# 5324    red            6.8             0.620         0.08             1.9
# 5325    red            6.2             0.600         0.08             2.0
# 5326    red            5.9             0.550         0.10             2.2
# 5327    red            5.9             0.645         0.12             2.0
# 5328    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df5.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            6.2              0.32         0.16             7.0
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.045                 30.0                 136.0   0.9949  3.18
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
df5.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    5329.000000       5329.000000  5329.000000     5329.000000
# mean        7.216573          0.344123     0.318738        5.053839
# std         1.317955          0.168102     0.147075        4.503160
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.240000        1.800000
# 50%         7.000000          0.300000     0.310000        2.700000
# 75%         7.700000          0.410000     0.400000        7.500000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  5329.000000          5329.000000           5329.000000  5329.000000
# mean      0.056668            30.060143            114.189341     0.994536
# std       0.036838            17.815588             56.781422     0.002966
# ...

# %%
df5.isnull().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df5.to_csv("wine_cleaned.csv")

# %%
df5.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            6.2              0.32         0.16             7.0
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.045                 30.0                 136.0   0.9949  3.18
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
df4.head()
# Out:
#    number of fires state    month  year      date
# 0              0.0  Acre  January  2000  1/1/2000
# 1              0.0  Acre  January  2002  1/1/2002
# 2             10.0  Acre  January  2003  1/1/2003
# 3              0.0  Acre  January  2004  1/1/2004
# 4             12.0  Acre  January  2005  1/1/2005

# %%
df4=df4[df4.columns[[3,2,1,0]]]
df4
# Out:
#       year     month      state  number of fires
# 0     2000   January       Acre              0.0
# 1     2002   January       Acre              0.0
# 2     2003   January       Acre             10.0
# 3     2004   January       Acre              0.0
# 4     2005   January       Acre             12.0
# ...    ...       ...        ...              ...
# 6446  2012  December  Tocantins            128.0
# 6447  2013  December  Tocantins             85.0
# 6448  2014  December  Tocantins            223.0
# 6449  2015  December  Tocantins            373.0
# 6450  2016  December  Tocantins            119.0
#
# [6451 rows x 4 columns]

# %%
df4
# Out:
#       year     month      state  number of fires
# 0     2000   January       Acre              0.0
# 1     2002   January       Acre              0.0
# 2     2003   January       Acre             10.0
# 3     2004   January       Acre              0.0
# 4     2005   January       Acre             12.0
# ...    ...       ...        ...              ...
# 6446  2012  December  Tocantins            128.0
# 6447  2013  December  Tocantins             85.0
# 6448  2014  December  Tocantins            223.0
# 6449  2015  December  Tocantins            373.0
# 6450  2016  December  Tocantins            119.0
#
# [6451 rows x 4 columns]
