# %% [markdown]
# <a href="https://colab.research.google.com/github/dpkasahu/Python_library/blob/main/titanic_data3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/whoknowayush/DataAnalysis-Dataset/refs/heads/main/Datasets-Practice/titanic.csv')
df.head()
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
#
#    sibsp  parch  ticket      fare    cabin embarked  survived
# 0      0      0   24160  211.3375       B5        S         1
# 1      1      2  113781  151.5500  C22 C26        S         1
# 2      1      2  113781  151.5500  C22 C26        S         0
# 3      1      2  113781  151.5500  C22 C26        S         0
# 4      1      2  113781  151.5500  C22 C26        S         0

# %%
# df['title'] = df['name'].str.split(',').str[1].str.split('.').str[0].str.strip()
df['title'] = [name.split(',')[1].split('.')[0].strip() for name in df['name']]
df['fname'] = df['name'].str.extract(r'\.\s*([A-Za-z]+)')[0]
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived  \
# ...

# %%
df.groupby('pclass')

# %%
df['pclass'].unique()

# %%
df['pclass'].value_counts()
# Out:
# pclass
# 3    709
# 1    323
# 2    277
# Name: count, dtype: int64

# %%
df.groupby('survived').get_group(1)
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 5          1                              Anderson, Mr. Harry    male
# 6          1                Andrews, Miss. Kornelia Theodosia  female
# 8          1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# ...      ...                                              ...     ...
# 1261       3                           Turkula, Mrs. (Hedwig)  female
# 1277       3                             Vartanian, Mr. David    male
# 1286       3  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)  female
# 1290       3                 Wilkes, Mrs. James (Ellen Needs)  female
# 1300       3          Yasbeck, Mrs. Antoni (Selini Alexander)  female
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived  \
# ...

# %%
df.groupby('sex').get_group('female').groupby('survived').get_group(1)
# Out:
#       pclass                                               name     sex   age  \
# 0          1                      Allen, Miss. Elisabeth Walton  female  29.0
# 6          1                  Andrews, Miss. Kornelia Theodosia  female  63.0
# 8          1      Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0
# 11         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.0
# 12         1                      Aubart, Mme. Leontine Pauline  female  24.0
# ...      ...                                                ...     ...   ...
# 1260       3                            Turja, Miss. Anna Sofia  female  18.0
# 1261       3                             Turkula, Mrs. (Hedwig)  female  63.0
# 1286       3    Whabee, Mrs. George Joseph (Shawneene Abi-Saab)  female  38.0
# 1290       3                   Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 1300       3            Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0
#
# ...

# %%
df[(df['sex']=='female') & (df['survived']==1)]
# Out:
#       pclass                                               name     sex   age  \
# 0          1                      Allen, Miss. Elisabeth Walton  female  29.0
# 6          1                  Andrews, Miss. Kornelia Theodosia  female  63.0
# 8          1      Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0
# 11         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.0
# 12         1                      Aubart, Mme. Leontine Pauline  female  24.0
# ...      ...                                                ...     ...   ...
# 1260       3                            Turja, Miss. Anna Sofia  female  18.0
# 1261       3                             Turkula, Mrs. (Hedwig)  female  63.0
# 1286       3    Whabee, Mrs. George Joseph (Shawneene Abi-Saab)  female  38.0
# 1290       3                   Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 1300       3            Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0
#
# ...

# %%
#age>25 sibsp=2 embarked=s
# df[(df['age']>25)&(df['sibsp']==2)&(df['embarked']=='S')]
temp = df.groupby('sibsp').get_group(2) \
         .groupby('embarked').get_group('S')
result = temp[temp['age'] > 25]
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived  \
# ...
