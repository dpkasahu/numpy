# %% [markdown]
# <a href="https://colab.research.google.com/github/dpkasahu/Python_library/blob/main/emp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/whoknowayush/DataAnalysis-Dataset/refs/heads/main/Datasets-Practice/employee_data.csv')
df
# Out:
#     emp_id             full_name   age  gender department   salary  \
# 0      101         John A. Smith  28.0    male      Sales  45000.0
# 1      102    Sarah-Louise James   NaN  female  Marketing  50000.0
# 2      110          Rajesh Kumar  45.0    male      Sales  90000.0
# 3      103        Mark O'Donnell  35.0    male         HR  52000.0
# 4      104   Emily Jackson-Smith  29.0  female        R&D  65000.0
# 5      102    Sarah-Louise James   NaN  female  Marketing  50000.0
# 6      110          Rajesh Kumar  45.0    male      Sales  90000.0
# 7      105     Samuel L. Jackson  42.0    Male         IT      NaN
# 8      106           Priya Ghosh  31.0     NaN  Marketing  58000.0
# 9      102    Sarah-Louise James   NaN  female  Marketing  50000.0
# 10     110          Rajesh Kumar  45.0    male      Sales  90000.0
# 11     107     Susan M. Thompson  39.0  Female         IT  75000.0
# 12     108     Brian P. McDonald  33.0    Male         HR  48000.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   emp_id      16 non-null     int64
#  1   full_name   16 non-null     object
#  2   age         12 non-null     float64
#  3   gender      15 non-null     object
#  4   department  16 non-null     object
#  5   salary      15 non-null     float64
#  6   join_date   15 non-null     object
#  7   exp_years   11 non-null     float64
#  8   emp_status  15 non-null     object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 1.3+ KB

# %%
mean=df['age'].mean()
df['age']=df['age'].fillna(mean).astype(int)
df
# Out:
#     emp_id             full_name  age  gender department   salary   join_date  \
# 0      101         John A. Smith   28    male      Sales  45000.0  2017-08-19
# 1      102    Sarah-Louise James   36  female  Marketing  50000.0  2018-11-03
# 2      110          Rajesh Kumar   45    male      Sales  90000.0  2010-02-23
# 3      103        Mark O'Donnell   35    male         HR  52000.0  2016-03-11
# 4      104   Emily Jackson-Smith   29  female        R&D  65000.0         NaN
# 5      102    Sarah-Louise James   36  female  Marketing  50000.0  2018-11-03
# 6      110          Rajesh Kumar   45    male      Sales  90000.0  2010-02-23
# 7      105     Samuel L. Jackson   42    Male         IT      NaN  2015-07-01
# 8      106           Priya Ghosh   31     NaN  Marketing  58000.0  2019-01-10
# 9      102    Sarah-Louise James   36  female  Marketing  50000.0  2018-11-03
# 10     110          Rajesh Kumar   45    male      Sales  90000.0  2010-02-23
# ...

# %%
df.loc[8,'gender']='Female'

# %%
mean_IT_sal=df.groupby('department').get_group('IT')['salary'].mean()

# %%
df['salary']=df['salary'].fillna(mean_IT_sal)

# %%
df.columns = df.columns.str.upper()
df
# Out:
#     EMP_ID             FULL_NAME  AGE  GENDER DEPARTMENT   SALARY   JOIN_DATE  \
# 0      101         John A. Smith   28    male      Sales  45000.0  2017-08-19
# 1      102    Sarah-Louise James   36  female  Marketing  50000.0  2018-11-03
# 2      110          Rajesh Kumar   45    male      Sales  90000.0  2010-02-23
# 3      103        Mark O'Donnell   35    male         HR  52000.0  2016-03-11
# 4      104   Emily Jackson-Smith   29  female        R&D  65000.0         NaN
# 5      102    Sarah-Louise James   36  female  Marketing  50000.0  2018-11-03
# 6      110          Rajesh Kumar   45    male      Sales  90000.0  2010-02-23
# 7      105     Samuel L. Jackson   42    Male         IT  65000.0  2015-07-01
# 8      106           Priya Ghosh   31  Female  Marketing  58000.0  2019-01-10
# 9      102    Sarah-Louise James   36  female  Marketing  50000.0  2018-11-03
# 10     110          Rajesh Kumar   45    male      Sales  90000.0  2010-02-23
# ...

# %%
df["JOIN_DATE"] = pd.to_datetime(df["JOIN_DATE"])
df["EMP_STATUS"] = df["EMP_STATUS"].str.lower()

# %%
df["ACTIVE"] = df["EMP_STATUS"] == "permanent"

# %%
df[
    (df["ACTIVE"] == True) &
    (df["EXP_YEARS"] >= 5) &
    (df["SALARY"] > 50000)
]
# Out:
#     EMP_ID          FULL_NAME  AGE GENDER DEPARTMENT   SALARY  JOIN_DATE  \
# 2      110       Rajesh Kumar   45   male      Sales  90000.0 2010-02-23
# 6      110       Rajesh Kumar   45   male      Sales  90000.0 2010-02-23
# 7      105  Samuel L. Jackson   42   Male         IT  65000.0 2015-07-01
# 10     110       Rajesh Kumar   45   male      Sales  90000.0 2010-02-23
# 14     110       Rajesh Kumar   45   male      Sales  90000.0 2010-02-23
#
#     EXP_YEARS EMP_STATUS  ACTIVE
# 2        14.0  permanent    True
# 6        14.0  permanent    True
# 7        12.0  permanent    True
# 10       14.0  permanent    True
# 14       14.0  permanent    True

# %%
df
# Out:
#     EMP_ID             FULL_NAME  AGE  GENDER DEPARTMENT   SALARY  JOIN_DATE  \
# 0      101         John A. Smith   28    male      Sales  45000.0 2017-08-19
# 1      102    Sarah-Louise James   36  female  Marketing  50000.0 2018-11-03
# 2      110          Rajesh Kumar   45    male      Sales  90000.0 2010-02-23
# 3      103        Mark O'Donnell   35    male         HR  52000.0 2016-03-11
# 4      104   Emily Jackson-Smith   29  female        R&D  65000.0        NaT
# 5      102    Sarah-Louise James   36  female  Marketing  50000.0 2018-11-03
# 6      110          Rajesh Kumar   45    male      Sales  90000.0 2010-02-23
# 7      105     Samuel L. Jackson   42    Male         IT  65000.0 2015-07-01
# 8      106           Priya Ghosh   31  Female  Marketing  58000.0 2019-01-10
# 9      102    Sarah-Louise James   36  female  Marketing  50000.0 2018-11-03
# 10     110          Rajesh Kumar   45    male      Sales  90000.0 2010-02-23
# ...

# %%
df["YEARS_WITH_COMPANY"] = 2025 - df["JOIN_DATE"].dt.year

# %%
df["SENIOR"] = df["EXP_YEARS"] >= 10

# %%
df["FIRST_NAME"] = df["FULL_NAME"].str.split().str[0]
df["LAST_NAME"] = df["FULL_NAME"].str.split().str[-1]

# %%
df["EXP_AGE_RATIO"] = df["EXP_YEARS"] / df["AGE"]

# %%
df["NAME_LENGTH"] = df["FULL_NAME"].str.len()

# %%
df["DEPT_SENIORITY"] = df["DEPARTMENT"] + "_" + df["SENIOR"].astype(str)

# %%
df["SALARY_RELATIVE"] = df["SALARY"] / df.groupby("DEPARTMENT")["SALARY"].transform("mean")

# %%
df =df.set_index("EMP_ID")

# %%
df = df.reset_index()
df
# Out:
#     EMP_ID             FULL_NAME  AGE  GENDER DEPARTMENT   SALARY  JOIN_DATE  \
# 0      101         John A. Smith   28    male      Sales  45000.0 2017-08-19
# 1      102    Sarah-Louise James   36  female  Marketing  50000.0 2018-11-03
# 2      110          Rajesh Kumar   45    male      Sales  90000.0 2010-02-23
# 3      103        Mark O'Donnell   35    male         HR  52000.0 2016-03-11
# 4      104   Emily Jackson-Smith   29  female        R&D  65000.0        NaT
# 5      102    Sarah-Louise James   36  female  Marketing  50000.0 2018-11-03
# 6      110          Rajesh Kumar   45    male      Sales  90000.0 2010-02-23
# 7      105     Samuel L. Jackson   42    Male         IT  65000.0 2015-07-01
# 8      106           Priya Ghosh   31  Female  Marketing  58000.0 2019-01-10
# 9      102    Sarah-Louise James   36  female  Marketing  50000.0 2018-11-03
# 10     110          Rajesh Kumar   45    male      Sales  90000.0 2010-02-23
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EMP_ID              16 non-null     int64
#  1   FULL_NAME           16 non-null     object
#  2   AGE                 16 non-null     int64
#  3   GENDER              16 non-null     object
#  4   DEPARTMENT          16 non-null     object
#  5   SALARY              16 non-null     float64
#  6   JOIN_DATE           15 non-null     datetime64[ns]
#  7   EXP_YEARS           11 non-null     float64
#  8   EMP_STATUS          15 non-null     object
#  9   ACTIVE              16 non-null     bool
#  10  YEARS_WITH_COMPANY  15 non-null     float64
#  11  SENIOR              16 non-null     bool
#  12  FIRST_NAME          16 non-null     object
#  13  LAST_NAME           16 non-null     object
#  14  EXP_AGE_RATIO       11 non-null     float64
# ...

# %%
df.to_csv('emp_cleaned')
