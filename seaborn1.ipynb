# %% [markdown]
# <a href="https://colab.research.google.com/github/dpkasahu/Python_library/blob/main/seaborn1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
sb1=pd.read_csv('https://raw.githubusercontent.com/whoknowayush/DataAnalysis-Dataset/refs/heads/main/Datasets-Practice/blinkit_cleaned%20(1)')
sb1
# Out:
#       Unnamed: 0 Item Fat Content Item Identifier              Item Type  \
# 0              0          Regular           FDX32  Fruits and Vegetables
# 1              1          Low Fat           NCB42     Health and Hygiene
# 2              2          Regular           FDR28           Frozen Foods
# 3              3          Regular           FDL50                 Canned
# 4              4          Low Fat           DRI25            Soft Drinks
# ...          ...              ...             ...                    ...
# 8518        8518          Low Fat           NCT53     Health and Hygiene
# 8519        8519          Low Fat           FDN09            Snack Foods
# 8520        8520          Low Fat           DRE13            Soft Drinks
# 8521        8521          Regular           FDT50                  Dairy
# 8522        8522          Regular           FDM58            Snack Foods
#
#       Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# ...

# %%
# sb2 = sb1.select_dtypes(include=['number'])
sb2 = sb1.iloc[:, [0, 4, 9, 10, 11, 12]]
sns.heatmap(sb2.corr(), annot=True,cmap='Greens')
# Out:
# <Axes: >
